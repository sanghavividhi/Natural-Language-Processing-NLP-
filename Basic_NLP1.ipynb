# %% [markdown]
# <a href="https://colab.research.google.com/github/sanghavividhi/Natural-Language-Processing-NLP-/blob/main/Session1NLP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
intval=10
print(intval)
print(intval,"type is=",type(intval))

floatval=10.12
print(floatval,"type is =",type(floatval))

stringval="abc"
print(stringval,"type is =",type(stringval))

listval=[1,"vidhi",10.5]
print(listval,"type is=",type(listval))
# Out:
# 10
# 10 type is= <class 'int'>
# 10.12 type is = <class 'float'>
# abc type is = <class 'str'>
# [1, 'vidhi', 10.5] type is= <class 'list'>

# %%
list1=['N','L','P','I','P','D','L']
print(list1[2])
print(list1[-1])
print(list1[1:4])
print(list1[2:6:2])
# Out:
# P
# L
# ['L', 'P', 'I']
# ['P', 'P']

# %%
vocab=["run","walk"]
print(vocab)
vocab.append("jump")
print(vocab)
vocab.extend(["swim","fly"])
print(vocab)
vocab.insert(1,"jog")
print(vocab)
# Out:
# ['run', 'walk']
# ['run', 'walk', 'jump']
# ['run', 'walk', 'jump', 'swim', 'fly']
# ['run', 'jog', 'walk', 'jump', 'swim', 'fly']

# %%
token=['the','model','trains','the','data']
print(token)
token.remove('the')
print(token)
token.pop(1)
print(token)
token.pop()
print(token)
# Out:
# ['the', 'model', 'trains', 'the', 'data']
# ['model', 'trains', 'the', 'data']
# ['model', 'the', 'data']
# ['model', 'the']

# %%
config={
    'color_space':"RCB",
    'blue_kernal':(5,5),
    'apply_thresold':True
}
print(config)
current_space=config['color_space']
print(current_space)
config['color_space']='GrayScale'
print(config)
config['edge_detection']='canny'
print(config)

print(config.keys())
print(config.values())
print(config.items())
# Out:
# {'color_space': 'RCB', 'blue_kernal': (5, 5), 'apply_thresold': True}
# RCB
# {'color_space': 'GrayScale', 'blue_kernal': (5, 5), 'apply_thresold': True}
# {'color_space': 'GrayScale', 'blue_kernal': (5, 5), 'apply_thresold': True, 'edge_detection': 'canny'}
# dict_keys(['color_space', 'blue_kernal', 'apply_thresold', 'edge_detection'])
# dict_values(['GrayScale', (5, 5), True, 'canny'])
# dict_items([('color_space', 'GrayScale'), ('blue_kernal', (5, 5)), ('apply_thresold', True), ('edge_detection', 'canny')])

# %%
raw_sentense="The CNN model identifies the features"
tokens=raw_sentense.lower().split()

tokens.remove("the")
tokens.remove("the")

tokens.append("<EOS>")
print(tokens)
# Out:
# ['cnn', 'model', 'identifies', 'features', '<EOS>']

# %%
image_meta={
    "filename":"frame_001.jpg",
    "dimensions":(1000,1920),
    "chanels":3,
    "format":"JPEG"
}

image_meta["format"]="PNG"

image_meta["Dounding_boxes"]=4
print(f"processing{image_meta['filename']} with {image_meta['chanels']} chanels")
# Out:
# processingframe_001.jpg with 3 chanels

# %%
#task 1

list=['frame_1.jpg',"frame_2.jpg",'frame_3.jpg','frame_4.jpg','frame_5.jpg','frame_6.jpg','frame_7.jpg','frame_8.jpg','frame_9.jpg','frame_10.jpg']
print(list)

print(list[2:7])
# Out:
# ['frame_1.jpg', 'frame_2.jpg', 'frame_3.jpg', 'frame_4.jpg', 'frame_5.jpg', 'frame_6.jpg', 'frame_7.jpg', 'frame_8.jpg', 'frame_9.jpg', 'frame_10.jpg']
# ['frame_3.jpg', 'frame_4.jpg', 'frame_5.jpg', 'frame_6.jpg', 'frame_7.jpg']

# %%
#task 2

sentence="data processing requires clean data"
words =sentence.split()

frequency={}

for word in words:
  frequency[word]=words.count(word)

print(frequency)
# Out:
# {'data': 2, 'processing': 1, 'requires': 1, 'clean': 1}

# %%
#task 3
datasets =[{
    "dataset_name":"training_set_v1",
    "num_images":50000,
    "resolution":(256,256),
    "labeled":True
},
{
  "dataset_name":"validate_set_v1",
  "num_images":10000,
  "resolution":(512,512),
  "labeled":False
}
]
print(datasets)
# Out:
# [{'dataset_name': 'training_set_v1', 'num_images': 50000, 'resolution': (256, 256), 'labeled': True}, {'dataset_name': 'validate_set_v1', 'num_images': 10000, 'resolution': (512, 512), 'labeled': False}]

# %%
from sys import float_repr_style
#task4

image_datset=[{
    "img_id":101,
    "filename":"skyline.jpg",
    "resolution":"1024x1080",
    "processed":False
},
{
   "img_id":102,
   "filename":"portrait.png",
   "resolution":"1024x768",
   "processed":False
}]
