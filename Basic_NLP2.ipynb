# %% [markdown]
# <a href="https://colab.research.google.com/github/sanghavividhi/Natural-Language-Processing-NLP-/blob/main/Copy_of_session2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def greet():
  print("hello world")
greet()
# Out:
# hello world

# %%
def add(a,b):
  return a+b
add(2,3)
# Out:
# 5

# %%
def student(name='guest'):
  print("welcome",name)

student("utang")
student()
# Out:
# welcome utang
# welcome guest

# %%
def square(x):
  return x*x
square(4)
# Out:
# 16

# %%
square=lambda x: x*x
print(square(2))
# Out:
# 4

# %%
with open('app.txt','w') as f:
  f.write("hello this is nlp text data ")

# %%
with open('app.txt','a') as f:
  f.write("\nadding a data to the file")

# %%
with open('app.txt','r') as f:
  print(f.read())
# Out:
# hello this is nlp text data adding a data to the file
# adding a data to the file

# %%
name=input("enter a name: ")
print("hello",name)
# Out:
# enter a name: utang
# hello utang

# %%
a=int(input("Enter a first no: "))
b=int(input('enter a second no:'))
def calculator(a,b):
  print('adding',a+b)
calculator(a,b)
# Out:
# Enter a first no: 12
# enter a second no:12
# adding 24

# %%
def log(data):
  with open("data.txt","w") as f:
    f.write(data)
prompt=input("enter a sentence:")
log(prompt)
# Out:
# enter a sentence:hello utang

# %%
# practice

# %%
def check(num):
  if num %2==0:
    print("no is even")
  else:
    print("no is odd")
value=int(input("enter a no: "))
check(value)
# Out:
# enter a no: 11
# no is odd

# %%
student_name = input("Enter student name: ")
with open('student_names.txt', 'a') as f:
  f.write(student_name + '\n')
# Out:
# Enter student name: utang

# %%
def add(x, y):
  return x + y

def subtract(x, y):
  return x - y

def multiply(x, y):
  return x * y

def divide(x, y):
  if y == 0:
    return "Error"
  return x / y

def calculator():
  print("Select operation:")
  print("1.Add")
  print("2.Subtract")
  print("3.Multiply")
  print("4.Divide")
  while True:
    choice = input("Enter choice(1/2/3/4): ")
    if choice in ('1', '2', '3', '4'):
      num1 = int(input("Enter first number: "))
      num2 = int(input("Enter second number: "))

      if choice == '1':
        print(num1, "+", num2, "=", add(num1, num2))
      elif choice == '2':
        print(num1, "-", num2, "=", subtract(num1, num2))
      elif choice == '3':
        print(num1, "*", num2, "=", multiply(num1, num2))
      elif choice == '4':
        print(num1, "/", num2, "=", divide(num1, num2))
      break

    else:
      print("Invalid input. Please enter 1, 2, 3, or 4.")


calculator()
# Out:
# Select operation:
# 1.Add
# 2.Subtract
# 3.Multiply
# 4.Divide
# Enter choice(1/2/3/4): 12
# Invalid input. Please enter 1, 2, 3, or 4.
# Enter choice(1/2/3/4): 12
# Invalid input. Please enter 1, 2, 3, or 4.
# Enter choice(1/2/3/4): 1
# Enter first number: 12
# Enter second number: 12
# 12 + 12 = 24

# %%
def count():
  with open("data.txt",'r') as f:
    data = f.read()
    words = data.split()
    print(len(data))
    return len(words)


count()
# Out:
# 11
# 2
